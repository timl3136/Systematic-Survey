# %%
# Get publication in 2018 (unfiltered)
import os

# %%
base_path = os.path.dirname(os.path.abspath(os.getcwd()))
folder_path = os.path.join(base_path, 'filter/pubmed_saved_raw/saved_raw')
file_list = os.listdir(folder_path)

# %%
from tqdm import tqdm
paper_dict = {}
for file in tqdm(file_list):
    file_path = os.path.join(folder_path, file)
    with open(file_path) as f:
        lines = f.readlines()
    for idx, line in enumerate(lines):
        
        if 'Pubmed-entry ::= {' in line:
            paper_dict[int(lines[idx+1].strip()[5:-1])] = int(lines[idx+4].strip()[-5:-1])
# Out:
# 100%|██████████| 167/167 [00:01<00:00, 122.80it/s]

# %%
paper_2018 = []
for x in paper_dict:
    if paper_dict[x] == 2018:
        paper_2018 =
# Out:
# {27302014: 2016,
#  28394179: 2017,
#  28552115: 2017,
#  28441235: 2017,
#  29233431: 2017,
#  29233429: 2017,
#  28715265: 2017,
#  28715262: 2017,
#  28661072: 2017,
#  28459258: 2017,
#  28295529: 2017,
#  28521196: 2017,
#  28508759: 2017,
#  27100266: 2016,
#  28474374: 2017,
#  28295794: 2017,
#  28511138: 2017,
#  27616303: 2016,
#  28478340: 2017,
#  28612635: 2017,
#  28443836: 2017,
#  28494321: 2017,
#  27815164: 2016,
#  28672147: 2017,
#  28525801: 2017,
#  28029434: 2016,
#  27618186: 2016,
#  28875056: 2017,
#  28690471: 2017,
#  29445779: 2018,
#  28814062: 2017,
#  28814060: 2017,
#  28814059: 2017,
#  28814054: 2017,
#  28814051: 2017,
#  28814049: 2017,
#  28814047: 2017,
#  28814043: 2017,
#  28814042: 2017,
#  28814041: 2017,
#  28814039: 2017,
#  28814031: 2017,
#  28814030: 2017,
#  28814029: 2017,
#  28814023: 2017,
#  28814021: 2017,
#  28814008: 2017,
#  28814006: 2017,
#  28814004: 2017,
#  28813999: 2017,
#  28813995: 2017,
#  28813994: 2017,
# ...
